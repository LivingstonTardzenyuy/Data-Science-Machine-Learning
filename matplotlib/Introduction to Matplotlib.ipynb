# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# ## Matplotlib example Workflow

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
# Another Scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from a dictionary
num_better = {
                "Almond butter": 10,
                "Peanut butter": 8,
                "Cashew butter":6
}
fig, ax = plt.subplots()
ax.bar(num_better.keys(), height=num_better.values());
ax.set(
    title="Dan's Nut butter store",
    xlabel="Butter",
    ylabel="Price ($)"
);

# %%
tatum_fc = {
    "Serge": 10,
    "Sule": 11,
    "Mustapha":12,
    "Cedric":17,
    "Kiply":23
}
fig,ax= plt.subplots()
ax.bar(tatum_fc.keys(), height=tatum_fc.values())
ax.set(
    title="Tatum FC",
    xlabel="Player Names",
    ylabel="Number of Goals"
);

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
import pandas as pd
import numpy as np
car_sales = pd.read_csv("51 - car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(
    np.random.randn(1000),
    index=pd.date_range("1/1/2020", periods=1000)
)
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales["Price"] = car_sales["Price"].str.replace(',', '').str.replace('$', '').astype(float)
# df1['Avg_Annual'] = df1['Avg_Annual'].str.replace(',', '').str.replace('$', '').astype(int)

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 528.0+ bytes

# %%
car_sales['Price Per Doors'] = car_sales["Price"] / car_sales["Doors"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Price Per Doors
# 0  Toyota  White         150043      4   4000.0      1000.000000
# 1   Honda    Red          87899      4   5000.0      1250.000000
# 2  Toyota   Blue          32549      3   7000.0      2333.333333
# 3     BMW  Black          11179      5  22000.0      4400.000000
# 4  Nissan  White         213095      4   3500.0       875.000000
# 5  Toyota  Green          99213      4   4500.0      1125.000000
# 6   Honda   Blue          45698      4   7500.0      1875.000000
# 7   Honda   Blue          54738      4   7000.0      1750.000000
# 8  Toyota  White          60000      4   6250.0      1562.500000
# 9  Nissan  White          31600      4   9700.0      2425.000000

# %%
car_sales.plot(x="Price", y="Price Per Doors");

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.641654  0.829562  0.306769  0.404104
# 1  0.482783  0.805957  0.933182  0.559126
# 2  0.400295  0.600850  0.262829  0.518052
# 3  0.697577  0.402543  0.048073  0.375113
# 4  0.607868  0.895392  0.138389  0.817675
# 5  0.447710  0.933097  0.898553  0.113222
# 6  0.473256  0.008129  0.111709  0.850818
# 7  0.092995  0.833889  0.490314  0.906410
# 8  0.017798  0.942486  0.541304  0.586025
# 9  0.211928  0.078074  0.897547  0.876077

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(
    kind="bar"
);

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Price Per Doors
# 0  Toyota  White         150043      4   4000.0      1000.000000
# 1   Honda    Red          87899      4   5000.0      1250.000000
# 2  Toyota   Blue          32549      3   7000.0      2333.333333
# 3     BMW  Black          11179      5  22000.0      4400.000000
# 4  Nissan  White         213095      4   3500.0       875.000000
# 5  Toyota  Green          99213      4   4500.0      1125.000000
# 6   Honda   Blue          45698      4   7500.0      1875.000000
# 7   Honda   Blue          54738      4   7000.0      1750.000000
# 8  Toyota  White          60000      4   6250.0      1562.500000
# 9  Nissan  White          31600      4   9700.0      2425.000000

# %%
car_sales.plot(
    kind="bar",
    x="Make",
    y="Odometer (KM)"
);

# %%
# Histograms
car_sales["Odometer (KM)"].plot(
    kind="hist"
);

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors         Price  Price Per Doors
# count      10.000000  10.000000     10.000000        10.000000
# mean    78601.400000   4.000000   7645.000000      1859.583333
# std     61983.471735   0.471405   5379.407753      1039.115487
# min     11179.000000   3.000000   3500.000000       875.000000
# 25%     35836.250000   4.000000   4625.000000      1156.250000
# 50%     57369.000000   4.000000   6625.000000      1656.250000
# 75%     96384.500000   4.000000   7375.000000      2218.750000
# max    213095.000000   5.000000  22000.000000      4400.000000

# %%
heart_disease = pd.read_csv("92 - heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histogram
heart_disease["age"].plot(
    kind="hist"
);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot(
    kind="hist"
);

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
len(over_50), len(heart_disease)
# Out:
# (208, 303)

# %%
import matplotlib.pyplot as plt

# %%
over_50.plot(
    kind="scatter",
    x="age",
    y="chol",
    c="target"
)
plt.title("Distribution of a Patient");

# %%
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(
    kind="scatter",
    x="age",
    y="chol",
    c="target",
    ax
)
# Out:
#   Cell In[36], line 7
#     ax
#     ^
# SyntaxError: positional argument follows keyword argument
